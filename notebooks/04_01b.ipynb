# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Matplotlib's Bar Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import DataFrame

# %%
data = {'names':['steve','john','richard','sarah','randy','michael','julie'],
'age': [20,22,20,21,24,23,22],
'gender': ['Male','Male','Male','Female','Male','Male','Female'],
'rank':[2,1,4,5,3,7,6] }
df = pd.DataFrame(data)

# %%
plt.bar(df['names'],df['age'])
plt.xlabel("name")
plt.ylabel("age")
plt.title("comparing ages")
plt.show()

# %% [markdown]
# Basically the same with: df.plot.barh(x = "names", y = "age")
# df.plot.bar(x = "names", y = "age")

# %%
plt.barh(df['names'], df['age'])
# Out:
# <BarContainer object of 7 artists>

# %%
plot=sns.barplot(data=df, x='names', y='age')
plot.set_title=('comparing ages')
plt.show()

# %% [markdown]
# ### Line Plot Matplotlib

# %%
plt.plot(df['names'], df['age'])
plt.title("comparing age")
# Out:
# Text(0.5, 1.0, 'comparing age')

# %% [markdown]
# ### Line Plot Seaborn

# %%
plot = sns.lineplot(data= df, x='names', y='age')
plot.set_title("comparing ages")
plt.show()

# %% [markdown]
# ### Pie Chart Matplotlib

# %%
plt.pie(df['age'], labels=df['names'])
plt.title("age comparison")
# Out:
# Text(0.5, 1.0, 'age comparison')

# %% [markdown]
# ### Pie Chart Seaborn

# %% [markdown]
# Seaborn doesn't have a default function to create pie charts, but we can use the syntax in Matplotlib to create a pie chart and then add the Seaborn color palette

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie(df['age'], labels=df['names'], colors=colors)
plt.show()
