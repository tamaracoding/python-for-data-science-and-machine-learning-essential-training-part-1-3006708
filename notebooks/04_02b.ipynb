# %% [markdown]
#  Imagine you are an E-commerce business analyst for a company that just made some major changes to its website layout. You are visualizing the site usability insights that you've discovered to convey findings to your manager. To do this, you use a line chart, a bar chart, and a pie chart.
#
#  You use a line chart to show how the total number of items purchased per day has increased since the change. You'll use the bar chart to show how the number of purchases increased for customers in the 18 to 25-year-old category, but that it decreased for customers in the greater than 44-year-old category. Lastly, you use a pie chart to show what categories of products generate the greatest proportion of sales and how the site changes affected that proportion, both before and after.
#
#  To summarize, you'd use a line chart to show the changes over time, you'd use a bar chart to show changes in categorical data, and you'd use a pie chart to visualize categorical data as a proportion of a whole.

# %% [markdown]
# ### Creating a line chart from a list object

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
plt.plot(x,y)

# %%
carname = cars['car_names']
carmpg = cars['mpg']
caronmpg = pd.concat([carname,carmpg], axis=1, ignore_index=False)

# %%
caronmpg.head()
# Out:
#            car_names   mpg
# 0          Mazda RX4  21.0
# 1      Mazda RX4 Wag  21.0
# 2         Datsun 710  22.8
# 3     Hornet 4 Drive  21.4
# 4  Hornet Sportabout  18.7

# %%
caronmpg.plot()
# Out:
# <Axes: >

# %%
mpg.plot()
# Out:
# <Axes: >

# %%
df = cars[['cyl','wt','mpg']]
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# #### Plotting a line chart in matplotlib

# %% [markdown]
# #### Plotting a line chart from a Pandas object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from pandas import DataFrame
from pandas import Series
from numpy.random import randn
from matplotlib.pyplot import rcParams

# %%
address = '/workspaces/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/data/mtcars.csv'

cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
mpg = cars['mpg']

# %% [markdown]
# ### Creating bar charts
# #### Creating a bar chart from a list

# %% [markdown]
# #### Creating bar charts from Pandas objects

# %%
mpg.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Creating a pie chart

# %% [markdown]
# ### Saving a plot

# %%
def countcars (s):
  return s.count()

# %%
cargrouped_bycyl=cars.groupby(['cyl']).agg(countcars)

# %%
cargrouped_bycyl
# Out:
#      car_names  mpg  disp  hp  drat  wt  qsec  vs  am  gear  carb
# cyl
# 4           11   11    11  11    11  11    11  11  11    11    11
# 6            7    7     7   7     7   7     7   7   7     7     7
# 8           14   14    14  14    14  14    14  14  14    14    14

# %%
data = {
    'nama_mobil': ['Mobil1', 'Mobil2', 'Mobil3', 'Mobil4', 'Mobil5', 'Mobil6', 'Mobil7', 'Mobil8', 'Mobil9', 'Mobil10', 'Mobil11', 'Mobil12', 'Mobil13', 'Mobil14', 'Mobil15', 'Mobil16', 'Mobil17', 'Mobil18', 'Mobil19', 'Mobil20'],
    'jumlah_silinder': [4, 6, 8, 4, 6, 8, 4, 6, 8, 4, 6, 8, 4, 6, 8, 4, 6, 8, 4, 6]
}

# %%
df = pd.DataFrame(data)

# %%
jumlah_mobil_per_silinder = df['jumlah_silinder'].value_counts()

# %%
jumlah_mobil_per_silinder
# Out:
# jumlah_silinder
# 4    7
# 6    7
# 8    6
# Name: count, dtype: int64

# %%
plt.pie(jumlah_mobil_per_silinder, labels=jumlah_mobil_per_silinder.index, autopct='%1.1f%%')
plt.title('Distribusi Jumlah Silinder Mobil')
plt.axis('equal')  # Memastikan pie chart berbentuk lingkaran
plt.show()

# %%
carcounts_percyl = cars['cyl'].value_counts()

# %%
carcounts_percyl
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
plt.pie(carcounts_percyl, labels=carcounts_percyl.index, autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.0999984052792728,
#  1.0999999240609177,
#  -1.099997108588521,
#  1.0999924685186595)

# %%
carcounts_percyl.plot.bar()
# Out:
# <Axes: xlabel='cyl'>

# %%
carcounts_percyl.plot(kind='bar')
# Out:
# <Axes: xlabel='cyl'>

# %%
carscyl = cars['cyl']
cars_dist = pd.concat([carscyl,carname], ignore_index=False, axis=1)
cars_dist.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 carscyl = cars['cyl']
# ----> 2 cars_dist = pd.concat([carscyl,carname], ignore_index=False, axis=1)
#       3 cars_dist.head()
#
# NameError: name 'carname' is not defined

# %%
carcounts_percyl.index
# Out:
# Index([8, 4, 6], dtype='int64', name='cyl')

# %%
plt.bar(carcounts_percyl.index, carcounts_percyl.values, color='#E5CCFF')
# Out:
# <BarContainer object of 3 artists>
